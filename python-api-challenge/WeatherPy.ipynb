# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dunedin
# Processing Record 2 of Set 1 | manicore
# Processing Record 3 of Set 1 | nova sintra
# Processing Record 4 of Set 1 | cooma
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | afaahiti
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | iskateley
# Processing Record 13 of Set 1 | mount pearl
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 16 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 17 of Set 1 | remire-montjoly
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | vernon
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | abepura
# Processing Record 22 of Set 1 | tazovsky
# Processing Record 23 of Set 1 | greymouth
# Processing Record 24 of Set 1 | margaret river
# Processing Record 25 of Set 1 | lorengau
# Processing Record 26 of Set 1 | wailua homesteads
# Processing Record 27 of Set 1 | palikir - national government center
# Processing Record 28 of Set 1 | acarau
# Processing Record 29 of Set 1 | dobryanka
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | necochea
# Processing Record 32 of Set 1 | aasiaat
# Processing Record 33 of Set 1 | anadyr
# Processing Record 34 of Set 1 | kurumkan
# Processing Record 35 of Set 1 | callao
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | pangoa
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | puerto deseado
# Processing Record 41 of Set 1 | nogliki
# Processing Record 42 of Set 1 | mandiana
# Processing Record 43 of Set 1 | adamstown
# Processing Record 44 of Set 1 | el daein
# City not found. Skipping...
# Processing Record 45 of Set 1 | ust-nera
# Processing Record 46 of Set 1 | dayrut
# Processing Record 47 of Set 1 | waitangi
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | ulladulla
# Processing Record 50 of Set 1 | bilibino
# Processing Record 0 of Set 2 | alo
# Processing Record 1 of Set 2 | erenhot
# Processing Record 2 of Set 2 | zhob
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | mejit
# Processing Record 5 of Set 2 | nagqu
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | gadzhiyevo
# Processing Record 8 of Set 2 | stanley
# Processing Record 9 of Set 2 | am timan
# Processing Record 10 of Set 2 | churapcha
# Processing Record 11 of Set 2 | chimbote
# Processing Record 12 of Set 2 | puerto natales
# Processing Record 13 of Set 2 | edinburgh of the seven seas
# Processing Record 14 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 15 of Set 2 | invercargill
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | sylva
# Processing Record 18 of Set 2 | la passe
# Processing Record 19 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 2 | soio
# Processing Record 21 of Set 2 | mirny
# Processing Record 22 of Set 2 | gazli
# Processing Record 23 of Set 2 | klyuchi
# Processing Record 24 of Set 2 | sinabang
# Processing Record 25 of Set 2 | havre
# Processing Record 26 of Set 2 | minot air force base
# Processing Record 27 of Set 2 | pariaman
# Processing Record 28 of Set 2 | altai
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | loch garman
# Processing Record 31 of Set 2 | olonkinbyen
# Processing Record 32 of Set 2 | sholinghur
# Processing Record 33 of Set 2 | susuman
# Processing Record 34 of Set 2 | saipan
# Processing Record 35 of Set 2 | tommot
# Processing Record 36 of Set 2 | linkou
# Processing Record 37 of Set 2 | camana
# Processing Record 38 of Set 2 | cristinapolis
# Processing Record 39 of Set 2 | morehead city
# Processing Record 40 of Set 2 | qamdo
# Processing Record 41 of Set 2 | bayan nur
# City not found. Skipping...
# Processing Record 42 of Set 2 | kamaishi
# Processing Record 43 of Set 2 | alajarvi
# Processing Record 44 of Set 2 | trenggalek
# Processing Record 45 of Set 2 | muana
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | saint-pierre
# Processing Record 49 of Set 2 | hadibu
# Processing Record 0 of Set 3 | lerwick
# Processing Record 1 of Set 3 | chernyshevskiy
# Processing Record 2 of Set 3 | ustka
# Processing Record 3 of Set 3 | bardai
# Processing Record 4 of Set 3 | kismayo
# Processing Record 5 of Set 3 | rockland
# Processing Record 6 of Set 3 | darwin
# Processing Record 7 of Set 3 | whitehorse
# Processing Record 8 of Set 3 | kerben
# Processing Record 9 of Set 3 | hawaiian paradise park
# Processing Record 10 of Set 3 | kununurra
# Processing Record 11 of Set 3 | sechura
# Processing Record 12 of Set 3 | chibougamau
# Processing Record 13 of Set 3 | ouadda
# Processing Record 14 of Set 3 | amga
# Processing Record 15 of Set 3 | canutama
# Processing Record 16 of Set 3 | dudinka
# Processing Record 17 of Set 3 | west island
# Processing Record 18 of Set 3 | badger
# Processing Record 19 of Set 3 | semera
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | glace bay
# Processing Record 22 of Set 3 | novodvinsk
# Processing Record 23 of Set 3 | heidelberg
# Processing Record 24 of Set 3 | phalodi
# Processing Record 25 of Set 3 | inari
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | trujillo
# Processing Record 28 of Set 3 | south lake tahoe
# Processing Record 29 of Set 3 | praia da vitoria
# Processing Record 30 of Set 3 | axim
# Processing Record 31 of Set 3 | polyarnyy
# Processing Record 32 of Set 3 | mazatlan
# Processing Record 33 of Set 3 | sungailiat
# Processing Record 34 of Set 3 | kingston
# Processing Record 35 of Set 3 | colonia
# Processing Record 36 of Set 3 | idri
# Processing Record 37 of Set 3 | taquarituba
# Processing Record 38 of Set 3 | old orchard beach
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | keffi
# Processing Record 41 of Set 3 | hirara
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | knyaze-volkonskoye
# Processing Record 44 of Set 3 | santa ana
# Processing Record 45 of Set 3 | atafu village
# Processing Record 46 of Set 3 | copiapo
# Processing Record 47 of Set 3 | porto novo
# Processing Record 48 of Set 3 | papatowai
# Processing Record 49 of Set 3 | zdunska wola
# Processing Record 0 of Set 4 | choibalsan
# Processing Record 1 of Set 4 | shimoda
# Processing Record 2 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 3 of Set 4 | prado
# Processing Record 4 of Set 4 | zholymbet
# Processing Record 5 of Set 4 | muynoq
# Processing Record 6 of Set 4 | bamboo flat
# Processing Record 7 of Set 4 | yamada
# Processing Record 8 of Set 4 | okha
# Processing Record 9 of Set 4 | kapa'a
# Processing Record 10 of Set 4 | dawei
# Processing Record 11 of Set 4 | betioky
# Processing Record 12 of Set 4 | kiunga
# Processing Record 13 of Set 4 | udachny
# Processing Record 14 of Set 4 | port lincoln
# Processing Record 15 of Set 4 | vila velha
# Processing Record 16 of Set 4 | abidjan
# Processing Record 17 of Set 4 | bandar abbas
# Processing Record 18 of Set 4 | selfoss
# Processing Record 19 of Set 4 | esperantinopolis
# Processing Record 20 of Set 4 | isafjordur
# Processing Record 21 of Set 4 | dungarpur
# Processing Record 22 of Set 4 | constantia
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | ingeniero guillermo n. juarez
# Processing Record 27 of Set 4 | port mathurin
# Processing Record 28 of Set 4 | barra de santo antonio
# Processing Record 29 of Set 4 | hermanus
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | wingham
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | siluko
# Processing Record 35 of Set 4 | chonchi
# Processing Record 36 of Set 4 | piti village
# Processing Record 37 of Set 4 | kalengwa
# Processing Record 38 of Set 4 | kayes
# Processing Record 39 of Set 4 | minas de marcona
# Processing Record 40 of Set 4 | agadez
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | sarmiento
# Processing Record 43 of Set 4 | chakwama
# City not found. Skipping...
# Processing Record 44 of Set 4 | fort irwin
# Processing Record 45 of Set 4 | pryor
# Processing Record 46 of Set 4 | alenquer
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | mcalester
# Processing Record 49 of Set 4 | bonito
# Processing Record 0 of Set 5 | luganville
# Processing Record 1 of Set 5 | ola
# Processing Record 2 of Set 5 | iqaluit
# Processing Record 3 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 4 of Set 5 | isangel
# Processing Record 5 of Set 5 | chigorodo
# Processing Record 6 of Set 5 | namie
# Processing Record 7 of Set 5 | vredendal
# Processing Record 8 of Set 5 | kogalym
# Processing Record 9 of Set 5 | manokwari
# Processing Record 10 of Set 5 | andkhoy
# Processing Record 11 of Set 5 | rio grande
# Processing Record 12 of Set 5 | lihue
# Processing Record 13 of Set 5 | fale old settlement
# Processing Record 14 of Set 5 | vyerkhnyadzvinsk
# Processing Record 15 of Set 5 | santiago de cao
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | san-pedro
# Processing Record 18 of Set 5 | poso
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | arauco
# Processing Record 21 of Set 5 | tolanaro
# Processing Record 22 of Set 5 | lebu
# Processing Record 23 of Set 5 | punta arenas
# Processing Record 24 of Set 5 | padre bernardo
# Processing Record 25 of Set 5 | utrik
# Processing Record 26 of Set 5 | mahabe
# City not found. Skipping...
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | raghogarh
# Processing Record 29 of Set 5 | dryden
# Processing Record 30 of Set 5 | wynyard
# Processing Record 31 of Set 5 | vorgashor
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | carauari
# Processing Record 36 of Set 5 | fort bragg
# Processing Record 37 of Set 5 | kourou
# Processing Record 38 of Set 5 | qaqortoq
# Processing Record 39 of Set 5 | molo
# Processing Record 40 of Set 5 | cananeia
# Processing Record 41 of Set 5 | leribe
# Processing Record 42 of Set 5 | majene
# Processing Record 43 of Set 5 | qui nhon
# Processing Record 44 of Set 5 | moyynkum
# Processing Record 45 of Set 5 | kulhudhuffushi
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | ta`u
# Processing Record 49 of Set 5 | nemuro
# Processing Record 0 of Set 6 | newman
# Processing Record 1 of Set 6 | maqat
# Processing Record 2 of Set 6 | asau village
# City not found. Skipping...
# Processing Record 3 of Set 6 | portland
# Processing Record 4 of Set 6 | krasnomayskiy
# Processing Record 5 of Set 6 | carbonear
# Processing Record 6 of Set 6 | uturoa
# Processing Record 7 of Set 6 | macclenny
# Processing Record 8 of Set 6 | kodiak
# Processing Record 9 of Set 6 | akot
# Processing Record 10 of Set 6 | massawa
# Processing Record 11 of Set 6 | christchurch
# Processing Record 12 of Set 6 | panguipulli
# Processing Record 13 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 6 | carutapera
# Processing Record 15 of Set 6 | hasaki
# Processing Record 16 of Set 6 | hamilton
# Processing Record 17 of Set 6 | nilsia
# Processing Record 18 of Set 6 | nyurba
# Processing Record 19 of Set 6 | puerto leguizamo
# Processing Record 20 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 21 of Set 6 | mar del plata
# Processing Record 22 of Set 6 | shalya
# Processing Record 23 of Set 6 | pontianak
# Processing Record 24 of Set 6 | vilyuchinsk
# Processing Record 25 of Set 6 | port saint john's
# Processing Record 26 of Set 6 | sal rei
# Processing Record 27 of Set 6 | liberal
# Processing Record 28 of Set 6 | pandan
# Processing Record 29 of Set 6 | sohbatpur
# Processing Record 30 of Set 6 | alofi
# Processing Record 31 of Set 6 | conceicao do araguaia
# Processing Record 32 of Set 6 | duyun
# Processing Record 33 of Set 6 | college
# Processing Record 34 of Set 6 | avarua
# Processing Record 35 of Set 6 | azovo
# Processing Record 36 of Set 6 | itaberai
# Processing Record 37 of Set 6 | santana
# Processing Record 38 of Set 6 | igrim
# Processing Record 39 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 6 | port-vila
# Processing Record 41 of Set 6 | sake
# Processing Record 42 of Set 6 | ooty
# Processing Record 43 of Set 6 | kasongo-lunda
# Processing Record 44 of Set 6 | simplicio mendes
# Processing Record 45 of Set 6 | howrah
# Processing Record 46 of Set 6 | batesville
# Processing Record 47 of Set 6 | as sulayyil
# Processing Record 48 of Set 6 | barakani
# Processing Record 49 of Set 6 | dwarka
# Processing Record 0 of Set 7 | vung tau
# Processing Record 1 of Set 7 | yuzhno-kurilsk
# Processing Record 2 of Set 7 | marsa alam
# Processing Record 3 of Set 7 | kem'
# Processing Record 4 of Set 7 | zhumysker
# Processing Record 5 of Set 7 | northam
# Processing Record 6 of Set 7 | oroqen zizhiqi
# Processing Record 7 of Set 7 | kahama
# Processing Record 8 of Set 7 | lander
# Processing Record 9 of Set 7 | itoman
# Processing Record 10 of Set 7 | korla
# Processing Record 11 of Set 7 | forster
# Processing Record 12 of Set 7 | pico truncado
# Processing Record 13 of Set 7 | aoulef
# Processing Record 14 of Set 7 | al kharijah
# Processing Record 15 of Set 7 | levuka
# Processing Record 16 of Set 7 | namibe
# Processing Record 17 of Set 7 | tadine
# Processing Record 18 of Set 7 | koungou
# Processing Record 19 of Set 7 | bubaque
# Processing Record 20 of Set 7 | saint-laurent-du-maroni
# Processing Record 21 of Set 7 | chinde
# Processing Record 22 of Set 7 | ascension
# Processing Record 23 of Set 7 | kailua-kona
# Processing Record 24 of Set 7 | labuan bajo
# Processing Record 25 of Set 7 | cidreira
# Processing Record 26 of Set 7 | tazacorte
# Processing Record 27 of Set 7 | camabatela
# Processing Record 28 of Set 7 | varash
# City not found. Skipping...
# Processing Record 29 of Set 7 | west end
# Processing Record 30 of Set 7 | irvine
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | papao
# Processing Record 33 of Set 7 | la gi
# Processing Record 34 of Set 7 | farasan
# Processing Record 35 of Set 7 | coxim
# Processing Record 36 of Set 7 | yemetsk
# Processing Record 37 of Set 7 | tafuna
# Processing Record 38 of Set 7 | floro
# Processing Record 39 of Set 7 | sarina
# Processing Record 40 of Set 7 | ejido benito juarez
# City not found. Skipping...
# Processing Record 41 of Set 7 | kone
# Processing Record 42 of Set 7 | tutong
# Processing Record 43 of Set 7 | lagoa
# Processing Record 44 of Set 7 | batu pahat
# Processing Record 45 of Set 7 | enewetak
# Processing Record 46 of Set 7 | pauini
# Processing Record 47 of Set 7 | kill devil hills
# Processing Record 48 of Set 7 | nova xavantina
# Processing Record 49 of Set 7 | port moresby
# Processing Record 0 of Set 8 | alegrete
# Processing Record 1 of Set 8 | la'ie
# Processing Record 2 of Set 8 | viedma
# Processing Record 3 of Set 8 | shenkursk
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | pacocha
# Processing Record 6 of Set 8 | abu jibeha
# Processing Record 7 of Set 8 | davydovka
# Processing Record 8 of Set 8 | ise
# Processing Record 9 of Set 8 | midvagur
# Processing Record 10 of Set 8 | nadi
# Processing Record 11 of Set 8 | castillos
# Processing Record 12 of Set 8 | leninskoye
# Processing Record 13 of Set 8 | omutinskiy
# Processing Record 14 of Set 8 | sorong
# Processing Record 15 of Set 8 | gaspe
# Processing Record 16 of Set 8 | camocim
# Processing Record 17 of Set 8 | batticaloa
# Processing Record 18 of Set 8 | pao de acucar
# Processing Record 19 of Set 8 | al ghayzah
# Processing Record 20 of Set 8 | puerto baquerizo moreno
# Processing Record 21 of Set 8 | nolinsk
# Processing Record 22 of Set 8 | ambalangoda
# Processing Record 23 of Set 8 | severo-yeniseyskiy
# Processing Record 24 of Set 8 | nar'yan-mar
# Processing Record 25 of Set 8 | sabha
# Processing Record 26 of Set 8 | araguaina
# Processing Record 27 of Set 8 | whangarei
# Processing Record 28 of Set 8 | kuhmo
# Processing Record 29 of Set 8 | kambar
# Processing Record 30 of Set 8 | shagamu
# Processing Record 31 of Set 8 | cidade velha
# Processing Record 32 of Set 8 | riachao das neves
# Processing Record 33 of Set 8 | ashland
# Processing Record 34 of Set 8 | vuktyl
# Processing Record 35 of Set 8 | jabat
# Processing Record 36 of Set 8 | flying fish cove
# Processing Record 37 of Set 8 | kapuskasing
# Processing Record 38 of Set 8 | poronaysk
# Processing Record 39 of Set 8 | maquoketa
# Processing Record 40 of Set 8 | yakeshi
# Processing Record 41 of Set 8 | aykhal
# Processing Record 42 of Set 8 | shibetsu
# Processing Record 43 of Set 8 | holualoa
# Processing Record 44 of Set 8 | afua
# Processing Record 45 of Set 8 | jiuquan
# Processing Record 46 of Set 8 | cill airne
# Processing Record 47 of Set 8 | badiyah
# Processing Record 48 of Set 8 | mananjary
# Processing Record 49 of Set 8 | mukalla
# Processing Record 0 of Set 9 | hohhot
# Processing Record 1 of Set 9 | ascope
# Processing Record 2 of Set 9 | weno
# Processing Record 3 of Set 9 | santa isabel
# Processing Record 4 of Set 9 | port blair
# Processing Record 5 of Set 9 | kas
# Processing Record 6 of Set 9 | kolonia town
# Processing Record 7 of Set 9 | alt-sanitz
# Processing Record 8 of Set 9 | east end village
# City not found. Skipping...
# Processing Record 9 of Set 9 | talnakh
# Processing Record 10 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 11 of Set 9 | akjoujt
# Processing Record 12 of Set 9 | chicomuselo
# Processing Record 13 of Set 9 | karratha
# Processing Record 14 of Set 9 | turkmenbasy
# Processing Record 15 of Set 9 | chamical
# Processing Record 16 of Set 9 | queenstown
# Processing Record 17 of Set 9 | salaga
# Processing Record 18 of Set 9 | san cristobal
# Processing Record 19 of Set 9 | tarauaca
# Processing Record 20 of Set 9 | san patricio
# Processing Record 21 of Set 9 | zangguy
# City not found. Skipping...
# Processing Record 22 of Set 9 | labrador city
# Processing Record 23 of Set 9 | mount isa
# Processing Record 24 of Set 9 | muisne
# Processing Record 25 of Set 9 | bukama
# Processing Record 26 of Set 9 | sao jose da coroa grande
# Processing Record 27 of Set 9 | lazaro cardenas
# Processing Record 28 of Set 9 | gryazovets
# Processing Record 29 of Set 9 | caluula
# Processing Record 30 of Set 9 | faya-largeau
# Processing Record 31 of Set 9 | alice springs
# Processing Record 32 of Set 9 | porto real do colegio
# Processing Record 33 of Set 9 | alasehir
# Processing Record 34 of Set 9 | harrison
# Processing Record 35 of Set 9 | antalaha
# Processing Record 36 of Set 9 | palora
# Processing Record 37 of Set 9 | dorchester
# Processing Record 38 of Set 9 | male
# Processing Record 39 of Set 9 | labytnangi
# Processing Record 40 of Set 9 | aldama
# Processing Record 41 of Set 9 | saldanha
# Processing Record 42 of Set 9 | altar
# Processing Record 43 of Set 9 | nuuk
# Processing Record 44 of Set 9 | abomsa
# Processing Record 45 of Set 9 | bonthe
# Processing Record 46 of Set 9 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 47 of Set 9 | keflavik
# Processing Record 48 of Set 9 | trinidad
# Processing Record 49 of Set 9 | miyanoura
# City not found. Skipping...
# Processing Record 0 of Set 10 | mizdah
# Processing Record 1 of Set 10 | sitia
# Processing Record 2 of Set 10 | howard springs
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | yuanping
# Processing Record 5 of Set 10 | crozon
# Processing Record 6 of Set 10 | paragominas
# Processing Record 7 of Set 10 | okhotsk
# Processing Record 8 of Set 10 | gashua
# Processing Record 9 of Set 10 | kilindoni
# Processing Record 10 of Set 10 | belyy yar
# Processing Record 11 of Set 10 | khilok
# Processing Record 12 of Set 10 | borogontsy
# Processing Record 13 of Set 10 | narrabri
# Processing Record 14 of Set 10 | rozhyshche
# Processing Record 15 of Set 10 | haiku-pauwela
# Processing Record 16 of Set 10 | gulf shores
# Processing Record 17 of Set 10 | ancud
# Processing Record 18 of Set 10 | los lunas
# Processing Record 19 of Set 10 | prachuap khiri khan
# Processing Record 20 of Set 10 | greensboro
# Processing Record 21 of Set 10 | gorontalo
# Processing Record 22 of Set 10 | bengkulu
# Processing Record 23 of Set 10 | saint-philippe
# Processing Record 24 of Set 10 | antananarivo
# Processing Record 25 of Set 10 | luwuk
# Processing Record 26 of Set 10 | hobyo
# Processing Record 27 of Set 10 | nanakuli
# Processing Record 28 of Set 10 | cockburn town
# Processing Record 29 of Set 10 | timashevsk
# Processing Record 30 of Set 10 | siverek
# Processing Record 31 of Set 10 | fortuna
# Processing Record 32 of Set 10 | tingo maria
# Processing Record 33 of Set 10 | alaghsas
# Processing Record 34 of Set 10 | rock springs
# Processing Record 35 of Set 10 | nsanje
# Processing Record 36 of Set 10 | benito garcia (el zorrillo)
# City not found. Skipping...
# Processing Record 37 of Set 10 | samamea
# City not found. Skipping...
# Processing Record 38 of Set 10 | turbat
# Processing Record 39 of Set 10 | miyaly
# Processing Record 40 of Set 10 | kruisfontein
# Processing Record 41 of Set 10 | amursk
# Processing Record 42 of Set 10 | moose jaw
# Processing Record 43 of Set 10 | st. john's
# Processing Record 44 of Set 10 | quang ngai
# Processing Record 45 of Set 10 | cabo san lucas
# Processing Record 46 of Set 10 | motueka
# Processing Record 47 of Set 10 | san antonio
# Processing Record 48 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 49 of Set 10 | marang
# Processing Record 0 of Set 11 | mana
# Processing Record 1 of Set 11 | mata-utu
# Processing Record 2 of Set 11 | naze
# Processing Record 3 of Set 11 | suva
# Processing Record 4 of Set 11 | suai
# City not found. Skipping...
# Processing Record 5 of Set 11 | kerikeri
# Processing Record 6 of Set 11 | piacabucu
# Processing Record 7 of Set 11 | tindouf
# Processing Record 8 of Set 11 | concepcion del bermejo
# Processing Record 9 of Set 11 | odda
# Processing Record 10 of Set 11 | santa rosalia
# Processing Record 11 of Set 11 | carnarvon
# Processing Record 12 of Set 11 | brisas de zicatela
# Processing Record 13 of Set 11 | greater sudbury
# Processing Record 14 of Set 11 | chabahar
# Processing Record 15 of Set 11 | ujae
# Processing Record 16 of Set 11 | miranda
# Processing Record 17 of Set 11 | mili
# Processing Record 18 of Set 11 | nakasongola
# Processing Record 19 of Set 11 | bikenibeu village
# Processing Record 20 of Set 11 | salym
# Processing Record 21 of Set 11 | lauro de freitas
# Processing Record 22 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 11 | holma
# Processing Record 24 of Set 11 | port hueneme
# Processing Record 25 of Set 11 | palembang
# Processing Record 26 of Set 11 | durban
# Processing Record 27 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 28 of Set 11 | koster
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | yangshuo
# Processing Record 32 of Set 11 | az zulfi
# Processing Record 33 of Set 11 | vega de alatorre
# Processing Record 34 of Set 11 | bentota
# Processing Record 35 of Set 11 | el granada
# Processing Record 36 of Set 11 | ubari
# Processing Record 37 of Set 11 | soe
# Processing Record 38 of Set 11 | ilhabela
# Processing Record 39 of Set 11 | pizarro
# Processing Record 40 of Set 11 | argo
# Processing Record 41 of Set 11 | homer
# Processing Record 42 of Set 11 | kupang
# Processing Record 43 of Set 11 | demmin
# Processing Record 44 of Set 11 | rundu
# Processing Record 45 of Set 11 | guilin
# Processing Record 46 of Set 11 | lethem
# Processing Record 47 of Set 11 | nuku'alofa
# Processing Record 48 of Set 11 | trincomalee
# Processing Record 49 of Set 11 | tosontsengel
# Processing Record 0 of Set 12 | sosnovo-ozerskoye
# Processing Record 1 of Set 12 | razlog
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | shahabad
# Processing Record 4 of Set 12 | new norfolk
# Processing Record 5 of Set 12 | seabra
# Processing Record 6 of Set 12 | mariinsk
# Processing Record 7 of Set 12 | gaigeturi
# Processing Record 8 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 9 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 10 of Set 12 | martil
# Processing Record 11 of Set 12 | soto la marina
# Processing Record 12 of Set 12 | brejo
# Processing Record 13 of Set 12 | valley city
# Processing Record 14 of Set 12 | tekkali
# Processing Record 15 of Set 12 | bodo
# Processing Record 16 of Set 12 | el nido
# Processing Record 17 of Set 12 | kharkhorin
# Processing Record 18 of Set 12 | chandler
# Processing Record 19 of Set 12 | kuta
# Processing Record 20 of Set 12 | show low
# Processing Record 21 of Set 12 | belmonte
# Processing Record 22 of Set 12 | gebeit
# Processing Record 23 of Set 12 | pachino
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | esquel
# Processing Record 26 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 27 of Set 12 | bo phloi
# Processing Record 28 of Set 12 | al burayqah
# Processing Record 29 of Set 12 | roma
# Processing Record 30 of Set 12 | fauske
# Processing Record 31 of Set 12 | harstad
# Processing Record 32 of Set 12 | zouerate
# Processing Record 33 of Set 12 | harar
# Processing Record 34 of Set 12 | hanover
# Processing Record 35 of Set 12 | clermont
# Processing Record 36 of Set 12 | siwa oasis
# Processing Record 37 of Set 12 | limassol
# Processing Record 38 of Set 12 | pangody
# Processing Record 39 of Set 12 | ha'il
# Processing Record 40 of Set 12 | sihanoukville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         dunedin -45.8742  170.5036     12.11        57          89
# 1        manicore  -5.8092  -61.3003     30.17        75          86
# 2     nova sintra  14.8667  -24.7167     21.26        69          60
# 3           cooma -36.2333  149.1333     14.31        63          77
# 4  ribeira grande  38.5167  -28.7000     18.22        77          20
#
#    Wind Speed Country        Date
# 0        0.45      NZ  1706983257
# 1        1.28      BR  1706983257
# 2        6.02      CV  1706983257
# 3        0.87      AU  1706982665
# 4        8.05      PT  1706983258

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               dunedin -45.8742  170.5036     12.11        57          89
# 1              manicore  -5.8092  -61.3003     30.17        75          86
# 2           nova sintra  14.8667  -24.7167     21.26        69          60
# 3                 cooma -36.2333  149.1333     14.31        63          77
# 4        ribeira grande  38.5167  -28.7000     18.22        77          20
#
#          Wind Speed Country        Date
# City_ID
# 0              0.45      NZ  1706983257
# 1              1.28      BR  1706983257
# 2              6.02      CV  1706983257
# 3              0.87      AU  1706982665
# 4              8.05      PT  1706983258

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Wind Speed"],
    edgecolor="black", 
    linewidths=1, 
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2            nova sintra  14.8667 -24.7167     21.26        69          60
# 4         ribeira grande  38.5167 -28.7000     18.22        77          20
# 10             iskateley  67.6803  53.1512    -12.77        86          20
# 11           mount pearl  47.5166 -52.7813     -1.75        87         100
# 13       remire-montjoly   4.9167 -52.2667     32.02        62          20
#
#          Wind Speed Country        Date
# City_ID
# 2              6.02      CV  1706983257
# 4              8.05      PT  1706983258
# 10             6.26      RU  1706983074
# 11             7.72      CA  1706983259
# 13             5.66      GF  1706983260

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               dunedin -45.8742  170.5036     12.11        57          89
# 1              manicore  -5.8092  -61.3003     30.17        75          86
# 3                 cooma -36.2333  149.1333     14.31        63          77
# 5         blackmans bay -43.0167  147.3167     15.29        86         100
# 6        port elizabeth -33.9180   25.5701     24.50        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.45      NZ  1706983257
# 1              1.28      BR  1706983257
# 3              0.87      AU  1706982665
# 5              2.24      AU  1706983258
# 6              3.09      ZA  1706983258

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
# Out:
# The r-value is: 0.7448464339655204

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 35))
# Out:
# The r-value is: 0.32349209114390226

# %% [markdown]
# **Discussion about the linear relationship:** The high `r` value indicates a strong positive correlation between latitude and max temperature. R values ~ 0.5 indicate that there is a moderate positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(40,10))
# Out:
# The r-value is: 0.18884729794294058

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50, 20))
# Out:
# The r-value is: 0.0636130593338521

# %% [markdown]
# **Discussion about the linear relationship:** The low `r` values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))
# Out:
# The r-value is: 0.0714108107882262

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-30,30))
# Out:
# The r-value is: 0.1082514991742267

# %% [markdown]
# **Discussion about the linear relationship:** The low `r` values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))
# Out:
# The r-value is: 0.005704631800356132

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 12))
# Out:
# The r-value is: 0.04057499216042037

# %% [markdown]
# **Discussion about the linear relationship:** The low `r` values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.
